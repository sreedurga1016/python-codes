# %% [markdown]
# <a href="https://colab.research.google.com/github/sreedurga1016/python-codes/blob/main/python_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#+ve and -ve numbers
num = float(input("enter a number :"))
if num>0:
  print("positive")
elif num == 0:
  print("zero")
else:
  print("negative")
# Out:
# enter a number :5
# positive

# %%
a = 5
b = 3
sum = a + b
print("Sum:", sum)
# Out:
# Sum: 8

# %%
#even numbers
num=int(input("enter a number:"))
if num%2==0:
  print("even")
else:
  print("odd")
# Out:
# enter a number:3
# odd

# %%
year = int(input("enter a year))
if(

# %%
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
a = 10
b = 25
c = 15

if a >= b and a >= c:
    print("Largest number is:", a)
elif b >= a and b >= c:
    print("Largest number is:", b)
else:
    print("Largest number is:", c)
# Out:
# Largest number is: 25

# %%
print("Hello, World!")
# Out:
# Hello, World!
